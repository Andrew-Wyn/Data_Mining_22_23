# %% [markdown]
# # Gaussian Naive Bayes Classifier
# We decided to implement a Gaussian Naive Bayes (GaussianNB) classifier using the scikit-learn library.

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_validate
import statistics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from classification_utils import *
import pickle
from sklearn.metrics import RocCurveDisplay

# %% [markdown]
# ## Loading data

# %%
data = pd.read_csv("../dataset/cleaned_user_profiles.csv", index_col=0)

# %%
data.head()
# Out:
#                         name lang  bot           created_at  statuses_count  \
# 2353593986   Lamonica Raborn   en    1  2019-02-22 18:00:42              76
# 2358850842     Lourie Botton   en    0  2019-02-26 03:02:32              54
# 137959629   Dadan Syarifudin   en    1  2015-04-30 07:09:56              53
# 466124818     Carletto Focia   it    1  2017-01-18 02:49:18              50
# 2571493866         MBK Ebook   en    0  2019-06-18 19:30:21            7085
#
#             avg_length  avg_special_chars  urls_ratio  mentions_ratio  \
# 2353593986   62.340909          14.015152    0.000000        0.272727
# 2358850842   69.082645          15.041322    0.000000        0.338843
# 137959629    65.340909          14.694444    0.000000        0.000000
# 466124818    86.944871          18.689463    0.022331        0.006281
# 2571493866   72.311246          14.582073    0.000825        0.506461
#
#             hashtags_ratio  reply_count_mean  reply_count_std  \
# 2353593986        0.098485               0.0              0.0
# 2358850842        0.024793               0.0              0.0
# 137959629         0.000000               0.0              0.0
# 466124818         0.072575               0.0              0.0
# 2571493866        0.118229               0.0              0.0
#
#             favorite_count_mean  favorite_count_std  favorite_count_entropy  \
# 2353593986             0.037879            0.190903                0.232481
# 2358850842             0.049587            0.217090                0.284639
# 137959629              0.000000            0.000000                0.000000
# 466124818              0.165387            0.530838                0.669155
# 2571493866             0.056365            0.243387                0.317182
#
#             retweet_count_mean  retweet_count_std  retweet_count_entropy
# 2353593986            0.037879           0.190903               0.232481
# 2358850842            0.024793           0.155495               0.167568
# 137959629             0.000000           0.000000              -0.000000
# 466124818             0.826239          13.034008               0.392850
# 2571493866            0.016772           0.142619               0.120737

# %%
#a descrption of the dataset
data.describe()
# Out:
#                 bot  statuses_count    avg_length  avg_special_chars  \
# count  11508.000000    11508.000000  11508.000000       11508.000000
# mean       0.531456     5148.794751     67.100135          15.045892
# std        0.499031    18496.606420     12.755296           2.454106
# min        0.000000        0.000000     32.500000           9.644166
# 25%        0.000000       53.000000     59.686796          13.553296
# 50%        1.000000       57.000000     65.340909          14.694444
# 75%        1.000000     2041.000000     74.254999          16.772205
# max        1.000000   399555.000000    104.449541          22.000000
#
#          urls_ratio  mentions_ratio  hashtags_ratio  reply_count_mean  \
# count  11508.000000    11508.000000    11508.000000      11508.000000
# mean       0.031045        0.347537        0.101921          0.001967
# std        0.053379        0.343735        0.093837          0.007796
# min        0.000000        0.000000        0.000000          0.000000
# 25%        0.000000        0.010260        0.045455          0.000000
# 50%        0.005109        0.303797        0.073394          0.000000
# 75%        0.037445        0.500000        0.128810          0.000000
# max        0.287760        1.726592        0.478261          0.044444
#
#        reply_count_std  favorite_count_mean  favorite_count_std  \
# count     11508.000000         11508.000000        11508.000000
# mean          0.023941             0.084282            0.365569
# std           0.068508             0.109623            0.408441
# min           0.000000             0.000000            0.000000
# 25%           0.000000             0.017751            0.136692
# 50%           0.000000             0.045752            0.230747
# 75%           0.000000             0.088862            0.451218
# max           0.333767             0.529903            2.183383
#
#        favorite_count_entropy  retweet_count_mean  retweet_count_std  \
# count            11508.000000        11508.000000       11508.000000
# mean                 0.385430           98.347409         361.956697
# std                  0.390787          329.248000         626.207734
# min                  0.000000            0.000000           0.000000
# 25%                  0.119116            0.022901           0.151796
# 50%                  0.268594            0.096931           0.437106
# 75%                  0.491767           74.499524         533.013057
# max                  1.723913        14432.000000        5442.443396
#
#        retweet_count_entropy
# count           11508.000000
# mean                1.011612
# std                 1.412183
# min                -0.000000
# 25%                 0.136059
# 50%                 0.312150
# 75%                 1.462435
# max                 9.161105

# %%
#check if there is any null value
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# In the following plot we can notice that the **Lang** feature is not well distribuited among all the possible languages, so we are going to make an analysis with and without the considered feature.

# %%
plot_lang_hist(data)

# %% [markdown]
# The following function discretizes the data using a function contained in _classification_utils.py_; the new added column is called _lang\_num_.

# %%
data = discretize_data(data, ["lang"])

# %%
data.head()
# Out:
#                         name lang  bot           created_at  statuses_count  \
# 2353593986   Lamonica Raborn   en    1  2019-02-22 18:00:42              76
# 2358850842     Lourie Botton   en    0  2019-02-26 03:02:32              54
# 137959629   Dadan Syarifudin   en    1  2015-04-30 07:09:56              53
# 466124818     Carletto Focia   it    1  2017-01-18 02:49:18              50
# 2571493866         MBK Ebook   en    0  2019-06-18 19:30:21            7085
#
#             avg_length  avg_special_chars  urls_ratio  mentions_ratio  \
# 2353593986   62.340909          14.015152    0.000000        0.272727
# 2358850842   69.082645          15.041322    0.000000        0.338843
# 137959629    65.340909          14.694444    0.000000        0.000000
# 466124818    86.944871          18.689463    0.022331        0.006281
# 2571493866   72.311246          14.582073    0.000825        0.506461
#
#             hashtags_ratio  reply_count_mean  reply_count_std  \
# 2353593986        0.098485               0.0              0.0
# 2358850842        0.024793               0.0              0.0
# 137959629         0.000000               0.0              0.0
# 466124818         0.072575               0.0              0.0
# 2571493866        0.118229               0.0              0.0
#
#             favorite_count_mean  favorite_count_std  favorite_count_entropy  \
# 2353593986             0.037879            0.190903                0.232481
# 2358850842             0.049587            0.217090                0.284639
# 137959629              0.000000            0.000000                0.000000
# 466124818              0.165387            0.530838                0.669155
# 2571493866             0.056365            0.243387                0.317182
#
#             retweet_count_mean  retweet_count_std  retweet_count_entropy  \
# 2353593986            0.037879           0.190903               0.232481
# 2358850842            0.024793           0.155495               0.167568
# 137959629             0.000000           0.000000              -0.000000
# 466124818             0.826239          13.034008               0.392850
# 2571493866            0.016772           0.142619               0.120737
#
#             lang_num
# 2353593986         4
# 2358850842         4
# 137959629          4
# 466124818          9
# 2571493866         4

# %% [markdown]
# We create the training and test set using a function available in classification_utils.py.

# %%
train_set, test_set, train_label, test_label = prepare_data(data)
# Out:
# Classification features : ['created_at', 'statuses_count', 'avg_length', 'avg_special_chars', 'urls_ratio', 'mentions_ratio', 'hashtags_ratio', 'reply_count_mean', 'reply_count_std', 'favorite_count_mean', 'favorite_count_std', 'favorite_count_entropy', 'retweet_count_mean', 'retweet_count_std', 'retweet_count_entropy', 'lang_num']

# %%
train_set.head()
# Out:
#             created_at  statuses_count  avg_length  avg_special_chars  \
# 2351467735  1550743978              53   46.951807           9.884337
# 347587058   1470273787              53   78.573190          17.079357
# 1129895606  1517367911              53   55.833333          12.611111
# 269193431   1458547948            9105   60.301689          12.949343
# 2368471386  1551683554              54   63.949580          15.117647
#
#             urls_ratio  mentions_ratio  hashtags_ratio  reply_count_mean  \
# 2351467735    0.000000        0.387952        0.038554               0.0
# 347587058     0.005109        0.000000        0.000000               0.0
# 1129895606    0.000000        0.000000        0.111111               0.0
# 269193431     0.051782        0.505816        0.036398               0.0
# 2368471386    0.000000        0.352941        0.084034               0.0
#
#             reply_count_std  favorite_count_mean  favorite_count_std  \
# 2351467735              0.0             0.043373            0.203696
# 347587058               0.0             0.013137            0.127206
# 1129895606              0.0             0.000000            0.000000
# 269193431               0.0             0.160600            0.495103
# 2368471386              0.0             0.050420            0.254332
#
#             favorite_count_entropy  retweet_count_mean  retweet_count_std  \
# 2351467735                0.257551            0.089157           1.095116
# 347587058                 0.098533            0.013137           0.122918
# 1129895606                0.000000            0.000000           0.000000
# 269193431                 0.661001          156.657786        1127.737572
# 2368471386                0.281797            0.016807           0.128547
#
#             retweet_count_entropy  lang_num
# 2351467735               0.249622         4
# 347587058                0.099408         4
# 1129895606              -0.000000         4
# 269193431                1.775016         4
# 2368471386               0.123115         4

# %%
train_label.head()
# Out:
# 2351467735    1
# 347587058     1
# 1129895606    1
# 269193431     0
# 2368471386    1
# Name: bot, dtype: int64

# %% [markdown]
# ### Usage of Lang
# We are going to train the model using also the **Lang** feature.

# %% [markdown]
# We apply the standard scaler transformation.

# %%
# To use GaussianNB we have to have gaussian distributed data, so apply standard scaler

scaler = StandardScaler()

train_X = scaler.fit_transform(train_set.values)
test_X = scaler.transform(test_set.values)

# %% [markdown]
# We create the model and we fit the training set.

# %%
#import, define and fit the model
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(train_X, train_label)

#predict on the test set
train_pred_gnb = gnb.predict(train_X)
test_pred_gnb = gnb.predict(test_X)

# %% [markdown]
# #### Printing metrics

# %%
print_metrics(train_label, train_pred_gnb, test_label, test_pred_gnb)
# Out:
# Accuracy train set  0.8438237119801366
# Accuracy test set  0.8375325803649001
# Precision train set  0.8582923522483318
# Recall train set  0.8438237119801366
# F1 score train set  0.8409438018571629
# Support train set  (array([0.93082192, 0.79435248]), array([0.72019078, 0.95281476]), array([0.81207051, 0.86639762]), array([3774, 4281]))

# %%
#compute the performance of the model
report_scores(test_label,test_pred_gnb)
# Out:
#               precision    recall  f1-score   support
#
#         <=50       0.92      0.71      0.80      1618
#          >50       0.79      0.95      0.86      1835
#
#     accuracy                           0.84      3453
#    macro avg       0.86      0.83      0.83      3453
# weighted avg       0.85      0.84      0.83      3453

# %%
# cross validation
scores = cross_validate(gnb, train_X, train_label, cv=3, return_train_score= True)
print('Fit time ', statistics.mean(scores['fit_time']))
print('Score time ', statistics.mean(scores['score_time']))
print('Test score ', statistics.mean(scores['test_score']))
print('Train score ', statistics.mean(scores['train_score']))
# Out:
# Fit time  0.0036165714263916016
# Score time  0.0011136531829833984
# Test score  0.843699565487275
# Train score  0.8436374922408442

# %% [markdown]
# #### Confusion Matrix

# %%
#it is possible to plot the confusion matrix 
#compute confusion matrix
cm = confusion_matrix(test_label, test_pred_gnb)
plot_confusion_matrix(gnb, test_X, test_label)
plt.show()
# Out:
# /Users/lucamoroni/Desktop/__WorkSpace/__Universita/unipi/DataMining/Data_Mining_22_23/venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# #### ROC curve

# %%
svc_disp = RocCurveDisplay.from_estimator(gnb, test_X, test_label)
plt.show()

# %% [markdown]
# #### PCA Blobs

# %%
pca = PCA(n_components=2)
test_set_reduced = pca.fit_transform(test_X)

# %%
#true labels
plt.scatter(test_set_reduced[:, 0], test_set_reduced[:, 1], c=test_label.values, s=25);

# %%
#predicted labels
plt.scatter(test_set_reduced[:, 0], test_set_reduced[:, 1], c=test_pred_gnb, s=25);

# %% [markdown]
# #### Saving the model

# %%
with open("../models_checkpoints/bn_lang.bin", "wb") as f:
    pickle.dump(gnb, f)

# %% [markdown]
# ### How lang is biased

# %%
# take a non bot user
non_bot_users = test_set[test_label==0]
total_bot = (test_label==0).sum()

# %%
test_set.head()
# Out:
#             created_at  statuses_count  avg_length  avg_special_chars  \
# 433346840   1481461640              53   76.367196          14.694444
# 3018833249  1581027304            3737   51.149189          10.895135
# 2352015044  1550770156              76   67.586207          14.765517
# 2192767087  1542308139            3395   55.013184          12.011866
# 31393396    1397737054           23508   62.396532          13.679769
#
#             urls_ratio  mentions_ratio  hashtags_ratio  reply_count_mean  \
# 433346840     0.005109        0.115344        0.092063               0.0
# 3018833249    0.123243        0.614054        0.127568               0.0
# 2352015044    0.000000        0.289655        0.048276               0.0
# 2192767087    0.030653        0.674687        0.141727               0.0
# 31393396      0.079383        0.751445        0.168015               0.0
#
#             reply_count_std  favorite_count_mean  favorite_count_std  \
# 433346840               0.0             0.001058            0.032513
# 3018833249              0.0             0.092973            0.431220
# 2352015044              0.0             0.055172            0.256752
# 2192767087              0.0             0.397825            0.230747
# 31393396                0.0             0.130250            0.408001
#
#             favorite_count_entropy  retweet_count_mean  retweet_count_std  \
# 433346840                 0.011985            0.502646           1.670232
# 3018833249                0.427675          270.823784        1375.382221
# 2352015044                0.307591            0.041379           0.199166
# 2192767087                0.736310          344.441332        1355.947138
# 31393396                  0.579183          213.348748         987.770289
#
#             retweet_count_entropy  lang_num
# 433346840                1.096014        15
# 3018833249               2.382324         4
# 2352015044               0.248581         4
# 2192767087               4.787768         4
# 31393396                 2.478715         4

# %%
non_bot_users_X = scaler.transform(non_bot_users.values)

# %%
gnb.predict(non_bot_users_X).sum()/total_bot
# Out:
# 0.2873918417799753

# %%
for lang in data.lang_num.unique():
    # substitute lang_num with 9 (italian), all the italian are bots
    modified_non_bot_users = non_bot_users.copy()
    modified_non_bot_users["lang_num"] = lang
    modified_non_bot_users.head()
    modified_non_bot_users_X = scaler.transform(modified_non_bot_users.values)
    print(f"number bot classified with lang_num = {lang} : {gnb.predict(modified_non_bot_users_X).sum()/total_bot}")
# Out:
# number bot classified with lang_num = 4 : 0.2861557478368356
# number bot classified with lang_num = 9 : 0.2941903584672435
# number bot classified with lang_num = 7 : 0.28862793572311496
# number bot classified with lang_num = 15 : 0.30778739184178
# number bot classified with lang_num = 5 : 0.2867737948084054
# number bot classified with lang_num = 17 : 0.311495673671199
# number bot classified with lang_num = 14 : 0.30716934487021014
# number bot classified with lang_num = 12 : 0.3009888751545117
# number bot classified with lang_num = 8 : 0.28986402966625463
# number bot classified with lang_num = 18 : 0.31396786155747836
# number bot classified with lang_num = 10 : 0.2985166872682324
# number bot classified with lang_num = 2 : 0.2867737948084054
# number bot classified with lang_num = 11 : 0.3003708281829419
# number bot classified with lang_num = 1 : 0.2873918417799753
# number bot classified with lang_num = 0 : 0.28862793572311496
# number bot classified with lang_num = 13 : 0.30284301606922126
# number bot classified with lang_num = 3 : 0.2867737948084054
# number bot classified with lang_num = 6 : 0.2873918417799753
# number bot classified with lang_num = 16 : 0.30902348578491967

# %% [markdown]
# ### No Usage of language

# %% [markdown]
# We delete the language feature on both training and test set.

# %%
del train_set["lang_num"]

# %%
train_set.head()
# Out:
#             created_at  statuses_count  avg_length  avg_special_chars  \
# 2351467735  1550743978              53   46.951807           9.884337
# 347587058   1470273787              53   78.573190          17.079357
# 1129895606  1517367911              53   55.833333          12.611111
# 269193431   1458547948            9105   60.301689          12.949343
# 2368471386  1551683554              54   63.949580          15.117647
#
#             urls_ratio  mentions_ratio  hashtags_ratio  reply_count_mean  \
# 2351467735    0.000000        0.387952        0.038554               0.0
# 347587058     0.005109        0.000000        0.000000               0.0
# 1129895606    0.000000        0.000000        0.111111               0.0
# 269193431     0.051782        0.505816        0.036398               0.0
# 2368471386    0.000000        0.352941        0.084034               0.0
#
#             reply_count_std  favorite_count_mean  favorite_count_std  \
# 2351467735              0.0             0.043373            0.203696
# 347587058               0.0             0.013137            0.127206
# 1129895606              0.0             0.000000            0.000000
# 269193431               0.0             0.160600            0.495103
# 2368471386              0.0             0.050420            0.254332
#
#             favorite_count_entropy  retweet_count_mean  retweet_count_std  \
# 2351467735                0.257551            0.089157           1.095116
# 347587058                 0.098533            0.013137           0.122918
# 1129895606                0.000000            0.000000           0.000000
# 269193431                 0.661001          156.657786        1127.737572
# 2368471386                0.281797            0.016807           0.128547
#
#             retweet_count_entropy
# 2351467735               0.249622
# 347587058                0.099408
# 1129895606              -0.000000
# 269193431                1.775016
# 2368471386               0.123115

# %%
del test_set["lang_num"]

# %%
test_set.head()
# Out:
#             created_at  statuses_count  avg_length  avg_special_chars  \
# 433346840   1481461640              53   76.367196          14.694444
# 3018833249  1581027304            3737   51.149189          10.895135
# 2352015044  1550770156              76   67.586207          14.765517
# 2192767087  1542308139            3395   55.013184          12.011866
# 31393396    1397737054           23508   62.396532          13.679769
#
#             urls_ratio  mentions_ratio  hashtags_ratio  reply_count_mean  \
# 433346840     0.005109        0.115344        0.092063               0.0
# 3018833249    0.123243        0.614054        0.127568               0.0
# 2352015044    0.000000        0.289655        0.048276               0.0
# 2192767087    0.030653        0.674687        0.141727               0.0
# 31393396      0.079383        0.751445        0.168015               0.0
#
#             reply_count_std  favorite_count_mean  favorite_count_std  \
# 433346840               0.0             0.001058            0.032513
# 3018833249              0.0             0.092973            0.431220
# 2352015044              0.0             0.055172            0.256752
# 2192767087              0.0             0.397825            0.230747
# 31393396                0.0             0.130250            0.408001
#
#             favorite_count_entropy  retweet_count_mean  retweet_count_std  \
# 433346840                 0.011985            0.502646           1.670232
# 3018833249                0.427675          270.823784        1375.382221
# 2352015044                0.307591            0.041379           0.199166
# 2192767087                0.736310          344.441332        1355.947138
# 31393396                  0.579183          213.348748         987.770289
#
#             retweet_count_entropy
# 433346840                1.096014
# 3018833249               2.382324
# 2352015044               0.248581
# 2192767087               4.787768
# 31393396                 2.478715

# %% [markdown]
# We scale the data using the standard scaler transformation.

# %%
scaler = StandardScaler()

train_X = scaler.fit_transform(train_set.values)
test_X = scaler.transform(test_set.values)

# %%
#import, define and fit the model
from sklearn.naive_bayes import GaussianNB

gnb2 = GaussianNB()
gnb2.fit(train_X, train_label)

#predict on the test set
train_pred_gnb = gnb2.predict(train_X)
test_pred_gnb = gnb2.predict(test_X)

# %% [markdown]
# #### Printing metrics

# %%
print_metrics(train_label, train_pred_gnb, test_label, test_pred_gnb)
# Out:
# Accuracy train set  0.837243947858473
# Accuracy test set  0.8285548798146539
# Precision train set  0.8485605216607158
# Recall train set  0.837243947858473
# F1 score train set  0.8346760957932784
# Support train set  (array([0.91091091, 0.79359431]), array([0.72337043, 0.93763139]), array([0.80638015, 0.85962094]), array([3774, 4281]))

# %%
#compute the performance of the model
report_scores(test_label,test_pred_gnb)
# Out:
#               precision    recall  f1-score   support
#
#         <=50       0.90      0.71      0.80      1618
#          >50       0.79      0.93      0.85      1835
#
#     accuracy                           0.83      3453
#    macro avg       0.84      0.82      0.82      3453
# weighted avg       0.84      0.83      0.83      3453

# %%
# cross validation
scores = cross_validate(gnb2, train_X, train_label, cv=3, return_train_score= True)
print('Fit time ', statistics.mean(scores['fit_time']))
print('Score time ', statistics.mean(scores['score_time']))
print('Test score ', statistics.mean(scores['test_score']))
print('Train score ', statistics.mean(scores['train_score']))
# Out:
# Fit time  0.0024613539377848306
# Score time  0.0011019706726074219
# Test score  0.8369956548727499
# Train score  0.8373680943513345

# %% [markdown]
# #### Confusion Matrix

# %%
#it is possible to plot the confusion matrix 
#compute confusion matrix
cm = confusion_matrix(test_label, test_pred_gnb)
plot_confusion_matrix(gnb2, test_X, test_label)
plt.show()
# Out:
# /Users/lucamoroni/Desktop/__WorkSpace/__Universita/unipi/DataMining/Data_Mining_22_23/venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# #### ROC Curve

# %%
svc_disp = RocCurveDisplay.from_estimator(gnb2, test_X, test_label)
plt.show()

# %% [markdown]
# #### PCA Blobs

# %%
pca = PCA(n_components=2)
test_set_reduced = pca.fit_transform(test_X)

# %%
#true labels
from sklearn.datasets import make_blobs
plt.scatter(test_set_reduced[:, 0], test_set_reduced[:, 1], c=test_label.values);

# %%
#predicted labels
plt.scatter(test_set_reduced[:, 0], test_set_reduced[:, 1], c=test_pred_gnb);

# %% [markdown]
# #### Saving the model

# %%
with open("../models_checkpoints/bn_no_lang.bin", "wb") as f:
    pickle.dump(gnb, f)
